# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/6/68/LOGO_UEU_BY_ASU-06.png" width=50% height=50%>
#
# <table style="width:75%">
#   <tr>
#     <td><b>Dosen Pengampu</b></td>
#     <td>Jefry Sunupurwa Asri , S.Kom., M.Kom.</td>
#    </tr>
#   <tr>
#     <td><b>Mahasiswa</b></td>
#     <td>Bagus Rosyid Hamdani</td>
#   </tr>
#   <tr>
#     <td><b>NIM</b></td>
#     <td>20210801467</td>
#   </tr>
#   <tr>
#     <td><b>Jurusan</b></td>
#     <td>Teknik Informatika</td>
#   </tr>
#   <tr>
#     <td><b>Mata Kuliah</b></td>
#     <td>Machine Learning</td>
#   </tr>
# </table>

# %%
# !pip install requests matplotlib seaborn wordcloud textblob
# Out:
# Requirement already satisfied: requests in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (2.31.0)
# Requirement already satisfied: matplotlib in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (3.8.0)
# Requirement already satisfied: seaborn in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (0.13.1)
# Requirement already satisfied: wordcloud in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (1.9.3)
# Requirement already satisfied: textblob in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (0.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from requests) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from requests) (2023.7.22)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: nltk>=3.1 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (2023.12.25)
# Requirement already satisfied: tqdm in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from nltk>=3.1->textblob) (4.66.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: colorama in c:\users\bagus\appdata\local\programs\python\python311\lib\site-packages (from click->nltk>=3.1->textblob) (0.4.6)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re
import nltk

# %%
nltk.download('punkt')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bagus\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\bagus\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
import requests

url = "https://shared.djambred.my.id/uas-nim-ganjil.txt"
response = requests.get(url)
text = response.text

# %%
text = "Long long time ago, in England in Sherwood Forest lived Robin Hood. When he was a boy , he had been cheated by a few noblemen. Since then he had decided that he would rob the rich and give what he got to the poor. The Sheriff of Nottingham had made an advertisement that he would give many rewards for the capture of Robin Hood, nobody had ever caught him. It was because Robin Hood had a number of friends who served him. They acted as informers. When the Sheriff had any plan to catch him, they would warn Robin Hood. Many rich people were scared of going through Sherwood Forest because they knew that Robin Hood would attack them. The Sheriff couldnâ€™t stand it anymore. Then he went to ask for the kingâ€™s help. However, the king refused to send any of his men to help in the capture of Robbin Hood. One day The Sheriff and the noblemen held a competition to choose the best shooter in Nottingham. It was for capturing Robin Hood. Robin Hood was an excellent shooter. Therefore, Robin Hood would participate in the competition to prove that he was the best. He had been warned by his servant, but Robin wasnâ€™t willing to listen. The competition began. William, The Sheriff man, and the man in green were trying for the first prize. it was time for the last arrow to be shot. The winner of this round would be declared the best shooter in Nottingham. William could shot very close to the center. Then the man in greenâ€™s turn made the crowd cheer hysterically. His arrow went through Williamâ€™s arrows and the center of the target. Then he shot two more arrows towards the chair on which the Sheriff sat. No doubt that the man in green was Robin Hood. immediately Robin Hood pulled of his black wig and then jumped over a wall onto his waiting horse and was gone. The Sheriff shouted to his men to catch him, but it was to late. Robin Hood escaped successfully."

processes_text = text.replace("â€™", "'")

print(processes_text)
# Out:
# Long long time ago, in England in Sherwood Forest lived Robin Hood. When he was a boy , he had been cheated by a few noblemen. Since then he had decided that he would rob the rich and give what he got to the poor. The Sheriff of Nottingham had made an advertisement that he would give many rewards for the capture of Robin Hood, nobody had ever caught him. It was because Robin Hood had a number of friends who served him. They acted as informers. When the Sheriff had any plan to catch him, they would warn Robin Hood. Many rich people were scared of going through Sherwood Forest because they knew that Robin Hood would attack them. The Sheriff couldn't stand it anymore. Then he went to ask for the king's help. However, the king refused to send any of his men to help in the capture of Robbin Hood. One day The Sheriff and the noblemen held a competition to choose the best shooter in Nottingham. It was for capturing Robin Hood. Robin Hood was an excellent shooter. Therefore, Robin Hood would participate in the competition to prove that he was the best. He had been warned by his servant, but Robin wasn't willing to listen. The competition began. William, The Sheriff man, and the man in green were trying for the first prize. it was time for the last arrow to be shot. The winner of this round would be declared the best shooter in Nottingham. William could shot very close to the center. Then the man in green's turn made the crowd cheer hysterically. His arrow went through William's arrows and the center of the target. Then he shot two more arrows towards the chair on which the Sheriff sat. No doubt that the man in green was Robin Hood. immediately Robin Hood pulled of his black wig and then jumped over a wall onto his waiting horse and was gone. The Sheriff shouted to his men to catch him, but it was to late. Robin Hood escaped successfully.

# %%
def preprocess_text(processes_text):
    processes_text = re.sub(r'[^\w\s]', '' , text)  # Menghapus tanda baca
    processes_text = processes_text.lower()  # Mengubah huruf menjadi lowercase
    return processes_text

processed_text = preprocess_text(processes_text)

# %%
def create_wordcloud(processed_text):
    # Membuat WordCloud
    wordcloud = WordCloud(width=800, height=400, max_words=200, background_color='yellow').generate(processed_text)

    # Plot WordCloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

create_wordcloud(processed_text)

# %%
import string
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt

def create_barplot(text, top_n=30):
    # Menghapus tanda baca dari teks
    text = text.translate(str.maketrans("", "", string.punctuation))

    # Tokenisasi teks
    tokens = word_tokenize(text)

    # Menghitung frekuensi kata-kata
    word_freq = Counter(tokens)

    # Mengambil N kata terbanyak
    top_words = dict(word_freq.most_common(top_n))

    # Plot barplot
    plt.figure(figsize=(12, 8))
    plt.bar(top_words.keys(), top_words.values())
    plt.xlabel('Kata')
    plt.ylabel('Frekuensi')
    plt.title(f'Barplot Frekuensi {top_n} Kata Terbanyak')
    plt.xticks(rotation=90, ha='right')
    plt.show()



# Membuat barplot dengan 20 kata terbanyak
create_barplot(text, top_n=30)

# %%
from textblob import TextBlob

# Menghitung sentimen
blob = TextBlob(text)
sentiment = blob.sentiment

print("Sentimen Keseluruhan:", sentiment)
# Out:
# Sentimen Keseluruhan: Sentiment(polarity=0.18205128205128204, subjectivity=0.46282051282051273)

# %%
def analyze_sentiment(text):
    sia = SentimentIntensityAnalyzer()
    sentiment_scores = sia.polarity_scores(text)
    sentiment_scores.pop('compound')
    
    plt.figure(figsize=(6, 4))
    plt.bar(sentiment_scores.keys(), sentiment_scores.values())
    plt.ylim(-1, 1)
    plt.show()
    
    for sentiment, score in sentiment_scores.items():
        if sentiment == 'negatif':
            print("Sentimen negatif:", score)
        elif sentiment == 'netral':
            print("Sentimen netral:", score)
        elif sentiment == 'positif':
            print("Sentimen positif:", score)

analyze_sentiment(processed_text)
